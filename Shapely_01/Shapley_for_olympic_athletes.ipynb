# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (0.40.0)
# Requirement already satisfied: numpy in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from shap) (1.21.5)
# Requirement already satisfied: packaging>20.9 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: cloudpickle in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from shap) (2.1.0)
# Requirement already satisfied: scikit-learn in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from shap) (1.0.2)
# Requirement already satisfied: numba in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from shap) (0.55.2)
# Requirement already satisfied: slicer==0.0.7 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from shap) (0.0.7)
# Requirement already satisfied: pandas in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from shap) (1.4.2)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from shap) (4.64.0)
# Requirement already satisfied: scipy in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from shap) (1.7.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from packaging>20.9->shap) (3.0.4)
# Requirement already satisfied: colorama in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from tqdm>4.25.0->shap) (0.4.4)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from numba->shap) (0.38.1)
# Requirement already satisfied: setuptools in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from numba->shap) (61.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from pandas->shap) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jstimolo\anaconda3\envs\mlg\lib\site-packages (from scikit-learn->shap) (2.2.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
import shap

# %%
df1 = pd.read_csv('Cleaned_Data.csv')
df1
# Out:
#         Unnamed: 0      ID                      Name  Sex  Age  Height  \
# 0                0       1                 A Dijiang    0   24     180
# 1                1       2                  A Lamusi    0   23     170
# 2                2       3       Gunnar Nielsen Aaby    0   24     178
# 3                3       4      Edgar Lindenau Aabye    0   34     182
# 4                4       5  Christine Jacoba Aaftink    1   21     185
# ...            ...     ...                       ...  ...  ...     ...
# 196751      271110  135568    Olga Igorevna Zyuzkova    1   33     171
# 196752      271111  135569                Andrzej ya    0   29     179
# 196753      271112  135570                  Piotr ya    0   27     176
# 196754      271114  135571        Tomasz Ireneusz ya    0   30     185
# 196755      271115  135571        Tomasz Ireneusz ya    0   34     185
#
#         Weight  NOC  Year          Sport  Winner
# 0           80  CHN  1992     Basketball       0
# 1           60  CHN  2012           Judo       0
# 2           73  DEN  1920       Football       0
# 3           95  DEN  1900     Tug-Of-War       1
# 4           82  NED  1988  Speed Skating       0
# ...        ...  ...   ...            ...     ...
# 196751      69  BLR  2016     Basketball       0
# 196752      89  POL  1976           Luge       0
# 196753      59  POL  2014    Ski Jumping       0
# 196754      96  POL  1998      Bobsleigh       0
# 196755      96  POL  2002      Bobsleigh       0
#
# [196756 rows x 11 columns]

# %% [markdown]
# Athletics
# Swimming
# Rowing
# Cycling
# Shooting

# %%
sports = ['Rowing', 'Athletics', 'Swimming', 'Cycling', 'Basketball']
sports
# Out:
# ['Rowing', 'Athletics', 'Swimming', 'Cycling', 'Basketball']

# %%
for s in sports:
    for g in range(2):

        # Processing Data:
        df2 = df1[(df1['Sport'] == s) & (df1['Sex'] == g)]
        df2 = df2.drop(columns = ['Sport', 'Unnamed: 0', 'ID', 'Name'])
        df2 = df2.drop(columns = ['NOC', 'Sex'])

        X_train = df2[df2['Year']<2016].drop(columns=['Winner', 'Year'])
        X_test = df2[df2['Year']==2016].drop(columns=['Winner', 'Year'])
        y_train = df2[df2['Year']<2016]['Winner']
        y_test = df2[df2['Year']==2016]['Winner']

        # Creating Model:
        xgb = XGBClassifier(random_state=42)
        xgb.fit(X_train, y_train)

        explainer = shap.TreeExplainer(xgb)
        data = df2.drop(columns=['Winner', 'Year'])

        # display(data)
        shap_values = explainer.shap_values(data)

        # Plot Results:
        
        
        if g==1:
            g = 'Female'
        else:
            g = 'Male'

        print('Influence_' + s + '_' + g)

        # Plot Influence on random Individual:
        shap.force_plot(explainer.expected_value, shap_values[1,:], data.iloc[1,:], show=True, matplotlib=True)

        # Plot Bar:
        """
        plt.grid(True)
        plt.title(s + ' '+ g, fontsize=20)
        plt.xlim(0, 1)
        shap.summary_plot(shap_values, X_test, plot_type='bar')
        """


        # Plot Violin:        
        """
        fig = shap.summary_plot(shap_values, data, feature_names=['Age', 'Height', 'Weight'], plot_type="violin", show=True)
        plt.title("bar")
        plt.show()
        """

None
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Rowing_Male
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Rowing_Female
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Athletics_Male
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Athletics_Female
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Swimming_Male
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Swimming_Female
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Cycling_Male
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Cycling_Female
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Basketball_Male
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# Influence_Basketball_Female
